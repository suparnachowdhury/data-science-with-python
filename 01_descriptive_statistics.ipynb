# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("HR Attrition.csv")

# View first rows
df.head()
# Out:
#    Age  Gender Attrition              Department  MonthlyIncome  \
# 0   41  Female       Yes                   Sales           5993
# 1   49    Male        No  Research & Development           5130
# 2   37    Male       Yes  Research & Development           2090
# 3   33  Female        No  Research & Development           2909
# 4   27    Male        No  Research & Development           3468
#
#    DistanceFromHome  JobSatisfaction  PerformanceRating  WorkLifeBalance  \
# 0                 1                4                  3                1
# 1                 8                2                  4                3
# 2                 2                3                  3                3
# 3                 3                3                  3                3
# 4                 2                2                  3                3
#
#    YearsAtCompany  Unnamed: 10  Unnamed: 11      Unnamed: 12 Unnamed: 13
# 0               6          NaN          NaN              NaN         NaN
# 1              10          NaN          NaN              NaN         NaN
# 2               0          NaN          NaN  Monthly Income          NaN
# 3               8          NaN          NaN          Mean =      $6,503
# 4               2          NaN          NaN        Median =         4919

# %%
df.shape
# Out:
# (1470, 14)

# %% [markdown]
# ### Understanding Variable Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                1470 non-null   int64
#  1   Gender             1470 non-null   object
#  2   Attrition          1470 non-null   object
#  3   Department         1470 non-null   object
#  4   MonthlyIncome      1470 non-null   int64
#  5   DistanceFromHome   1470 non-null   int64
#  6   JobSatisfaction    1470 non-null   int64
#  7   PerformanceRating  1470 non-null   int64
#  8   WorkLifeBalance    1470 non-null   int64
#  9   YearsAtCompany     1470 non-null   int64
#  10  Unnamed: 10        0 non-null      float64
#  11  Unnamed: 11        0 non-null      float64
#  12  Unnamed: 12        4 non-null      object
#  13  Unnamed: 13        2 non-null      object
# dtypes: float64(2), int64(7), object(5)
# memory usage: 160.9+ KB

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['Gender', 'Attrition', 'Department', 'Unnamed: 12', 'Unnamed: 13'], dtype='object')

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['Age', 'MonthlyIncome', 'DistanceFromHome', 'JobSatisfaction',
#        'PerformanceRating', 'WorkLifeBalance', 'YearsAtCompany', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# ### 3. Measures of Central Tendency

# %%
df["MonthlyIncome"].mean()
# Out:
# np.float64(6502.931292517007)

# %%
np.mean(df["MonthlyIncome"])
# Out:
# np.float64(6502.931292517007)

# %%
df["MonthlyIncome"].median()
# Out:
# np.float64(4919.0)

# %%
np.median(df["MonthlyIncome"])
# Out:
# np.float64(4919.0)

# %%
df["MonthlyIncome"].agg(["mean", "median"])
# Out:
# mean      6502.931293
# median    4919.000000
# Name: MonthlyIncome, dtype: float64

# %%
df["Department"].mode()[0]
# Out:
# 'Research & Development'

# %%
df["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Measures of Dispersion

# %%
income_range = df["MonthlyIncome"].max() - df["MonthlyIncome"].min()

income_range

# %%
df["MonthlyIncome"].var()

# %%
df["MonthlyIncome"].std()
